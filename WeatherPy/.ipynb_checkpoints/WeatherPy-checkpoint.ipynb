# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 603

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units=metric&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | qaqortoq
# Processing Record 2 of Set 1 | pokhara
# Processing Record 3 of Set 1 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 4 of Set 1 | port-aux-francais
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | vredefort
# Processing Record 7 of Set 1 | bethel
# Processing Record 8 of Set 1 | kincardine
# Processing Record 9 of Set 1 | tranovaho
# City not found. Skipping...
# Processing Record 10 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 11 of Set 1 | puerto natales
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | vilyuchinsk
# Processing Record 14 of Set 1 | ndjole
# Processing Record 15 of Set 1 | yaren
# Processing Record 16 of Set 1 | invercargill
# Processing Record 17 of Set 1 | iskateley
# Processing Record 18 of Set 1 | edinburgh of the seven seas
# Processing Record 19 of Set 1 | naama
# Processing Record 20 of Set 1 | longyearbyen
# Processing Record 21 of Set 1 | guerrero negro
# Processing Record 22 of Set 1 | enewetak
# Processing Record 23 of Set 1 | olinda
# Processing Record 24 of Set 1 | inongo
# Processing Record 25 of Set 1 | kiunga
# Processing Record 26 of Set 1 | ambatondrazaka
# Processing Record 27 of Set 1 | tegucigalpa
# Processing Record 28 of Set 1 | margaret river
# Processing Record 29 of Set 1 | shilovo
# Processing Record 30 of Set 1 | nikolayevsk-on-amure
# Processing Record 31 of Set 1 | olonkinbyen
# Processing Record 32 of Set 1 | chonchi
# Processing Record 33 of Set 1 | alvaraes
# Processing Record 34 of Set 1 | port elizabeth
# Processing Record 35 of Set 1 | bilibino
# Processing Record 36 of Set 1 | badger
# Processing Record 37 of Set 1 | georgetown
# Processing Record 38 of Set 1 | waitangi
# Processing Record 39 of Set 1 | grytviken
# Processing Record 40 of Set 1 | smithers
# Processing Record 41 of Set 1 | torghay
# Processing Record 42 of Set 1 | ust-tsilma
# Processing Record 43 of Set 1 | nyurba
# Processing Record 44 of Set 1 | island harbour
# Processing Record 45 of Set 1 | san andres
# Processing Record 46 of Set 1 | iqaluit
# Processing Record 47 of Set 1 | happy valley-goose bay
# Processing Record 48 of Set 1 | lakatoro
# Processing Record 49 of Set 1 | kulunda
# Processing Record 50 of Set 1 | svendborg
# Processing Record 0 of Set 2 | tiksi
# Processing Record 1 of Set 2 | bataipora
# Processing Record 2 of Set 2 | codrington
# Processing Record 3 of Set 2 | korla
# Processing Record 4 of Set 2 | sortavala
# Processing Record 5 of Set 2 | papatowai
# Processing Record 6 of Set 2 | prince rupert
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | avarua
# Processing Record 9 of Set 2 | adamstown
# Processing Record 10 of Set 2 | nemuro
# Processing Record 11 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 12 of Set 2 | saipan
# Processing Record 13 of Set 2 | pico truncado
# Processing Record 14 of Set 2 | robore
# Processing Record 15 of Set 2 | cambria
# Processing Record 16 of Set 2 | labytnangi
# Processing Record 17 of Set 2 | mejit
# Processing Record 18 of Set 2 | pimentel
# Processing Record 19 of Set 2 | cacapava do sul
# Processing Record 20 of Set 2 | ilulissat
# Processing Record 21 of Set 2 | zacualtipan
# Processing Record 22 of Set 2 | whakatane
# Processing Record 23 of Set 2 | st. john's
# Processing Record 24 of Set 2 | talnakh
# Processing Record 25 of Set 2 | stanley
# Processing Record 26 of Set 2 | puerto lempira
# Processing Record 27 of Set 2 | mmabatho
# Processing Record 28 of Set 2 | jamestown
# Processing Record 29 of Set 2 | anadyr
# Processing Record 30 of Set 2 | hithadhoo
# Processing Record 31 of Set 2 | gudauta
# Processing Record 32 of Set 2 | macau
# Processing Record 33 of Set 2 | hailar
# Processing Record 34 of Set 2 | laayoune plage
# City not found. Skipping...
# Processing Record 35 of Set 2 | eyl
# Processing Record 36 of Set 2 | ocean shores
# Processing Record 37 of Set 2 | santa cruz
# Processing Record 38 of Set 2 | mitu
# Processing Record 39 of Set 2 | north augusta
# Processing Record 40 of Set 2 | sinabang
# Processing Record 41 of Set 2 | merizo village
# Processing Record 42 of Set 2 | lisala
# Processing Record 43 of Set 2 | vila franca do campo
# Processing Record 44 of Set 2 | flying fish cove
# Processing Record 45 of Set 2 | constantia
# Processing Record 46 of Set 2 | fort bragg
# Processing Record 47 of Set 2 | kathu
# Processing Record 48 of Set 2 | hermanus
# Processing Record 49 of Set 2 | hitoyoshi
# Processing Record 0 of Set 3 | rio grande
# Processing Record 1 of Set 3 | coyhaique
# Processing Record 2 of Set 3 | chinde
# Processing Record 3 of Set 3 | ust-nera
# Processing Record 4 of Set 3 | laojunmiao
# Processing Record 5 of Set 3 | bathsheba
# Processing Record 6 of Set 3 | lebu
# Processing Record 7 of Set 3 | kaifeng
# Processing Record 8 of Set 3 | bridgewater
# Processing Record 9 of Set 3 | margate
# Processing Record 10 of Set 3 | afaahiti
# Processing Record 11 of Set 3 | zheleznodorozhnyy
# Processing Record 12 of Set 3 | shingu
# Processing Record 13 of Set 3 | san juan
# Processing Record 14 of Set 3 | college
# Processing Record 15 of Set 3 | nar'yan-mar
# Processing Record 16 of Set 3 | lompoc
# Processing Record 17 of Set 3 | san juan de miraflores
# Processing Record 18 of Set 3 | sumbawa besar
# Processing Record 19 of Set 3 | ulladulla
# Processing Record 20 of Set 3 | murzuq
# Processing Record 21 of Set 3 | alpena
# Processing Record 22 of Set 3 | mahina
# Processing Record 23 of Set 3 | blackmans bay
# Processing Record 24 of Set 3 | colares
# Processing Record 25 of Set 3 | walvis bay
# Processing Record 26 of Set 3 | thompson
# Processing Record 27 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 28 of Set 3 | vila velha
# Processing Record 29 of Set 3 | nogliki
# Processing Record 30 of Set 3 | tolanaro
# Processing Record 31 of Set 3 | puerto armuelles
# Processing Record 32 of Set 3 | utrik
# Processing Record 33 of Set 3 | chibougamau
# Processing Record 34 of Set 3 | gazojak
# Processing Record 35 of Set 3 | wailua homesteads
# Processing Record 36 of Set 3 | castillos
# Processing Record 37 of Set 3 | yellowknife
# Processing Record 38 of Set 3 | bodo
# Processing Record 39 of Set 3 | comodoro rivadavia
# Processing Record 40 of Set 3 | isafjordur
# Processing Record 41 of Set 3 | rapid city
# Processing Record 42 of Set 3 | west end
# Processing Record 43 of Set 3 | fonte boa
# Processing Record 44 of Set 3 | west island
# Processing Record 45 of Set 3 | whitehorse
# Processing Record 46 of Set 3 | cidreira
# Processing Record 47 of Set 3 | the pas
# Processing Record 48 of Set 3 | kandri
# Processing Record 49 of Set 3 | mandalgovi
# Processing Record 0 of Set 4 | musay'id
# City not found. Skipping...
# Processing Record 1 of Set 4 | ebon
# Processing Record 2 of Set 4 | bel ombre
# Processing Record 3 of Set 4 | bac lieu
# Processing Record 4 of Set 4 | ribeira grande
# Processing Record 5 of Set 4 | hawaiian paradise park
# Processing Record 6 of Set 4 | mount gambier
# Processing Record 7 of Set 4 | concepcion
# Processing Record 8 of Set 4 | 'amran
# City not found. Skipping...
# Processing Record 9 of Set 4 | thunder bay
# Processing Record 10 of Set 4 | corumba
# Processing Record 11 of Set 4 | denham springs
# Processing Record 12 of Set 4 | gadzhiyevo
# Processing Record 13 of Set 4 | ouellah
# City not found. Skipping...
# Processing Record 14 of Set 4 | lubango
# Processing Record 15 of Set 4 | namibe
# Processing Record 16 of Set 4 | bredasdorp
# Processing Record 17 of Set 4 | nishinoomote
# Processing Record 18 of Set 4 | guadalupe y calvo
# Processing Record 19 of Set 4 | geraldton
# Processing Record 20 of Set 4 | kone
# Processing Record 21 of Set 4 | baiyin
# Processing Record 22 of Set 4 | jayapura
# Processing Record 23 of Set 4 | sterling
# Processing Record 24 of Set 4 | mil'kovo
# Processing Record 25 of Set 4 | am timan
# Processing Record 26 of Set 4 | aksu
# Processing Record 27 of Set 4 | yanchep
# Processing Record 28 of Set 4 | tevriz
# Processing Record 29 of Set 4 | portland
# Processing Record 30 of Set 4 | port saint john's
# Processing Record 31 of Set 4 | toamasina
# Processing Record 32 of Set 4 | carnarvon
# Processing Record 33 of Set 4 | quzhou
# Processing Record 34 of Set 4 | aldan
# Processing Record 35 of Set 4 | ziro
# Processing Record 36 of Set 4 | olyokminsk
# Processing Record 37 of Set 4 | hirara
# Processing Record 38 of Set 4 | klyuchi
# Processing Record 39 of Set 4 | aykhal
# Processing Record 40 of Set 4 | brisas de zicatela
# Processing Record 41 of Set 4 | midvagur
# Processing Record 42 of Set 4 | nashtarud
# City not found. Skipping...
# Processing Record 43 of Set 4 | lautoka
# Processing Record 44 of Set 4 | orikhiv
# Processing Record 45 of Set 4 | atafu village
# Processing Record 46 of Set 4 | goaso
# City not found. Skipping...
# Processing Record 47 of Set 4 | puerto ayora
# Processing Record 48 of Set 4 | tazovsky
# Processing Record 49 of Set 4 | loango
# Processing Record 0 of Set 5 | rio gallegos
# Processing Record 1 of Set 5 | broome
# Processing Record 2 of Set 5 | zhaotong
# Processing Record 3 of Set 5 | tazacorte
# Processing Record 4 of Set 5 | coquimbo
# Processing Record 5 of Set 5 | kharp
# Processing Record 6 of Set 5 | remire-montjoly
# Processing Record 7 of Set 5 | arkhangel'sk
# Processing Record 8 of Set 5 | ivdel'
# Processing Record 9 of Set 5 | pemangkat
# Processing Record 10 of Set 5 | katsuren-haebaru
# Processing Record 11 of Set 5 | kodiak
# Processing Record 12 of Set 5 | arteche
# Processing Record 13 of Set 5 | den burg
# Processing Record 14 of Set 5 | queenstown
# Processing Record 15 of Set 5 | dudinka
# Processing Record 16 of Set 5 | sofifi
# City not found. Skipping...
# Processing Record 17 of Set 5 | jiayuguan
# Processing Record 18 of Set 5 | roma
# Processing Record 19 of Set 5 | uturoa
# Processing Record 20 of Set 5 | jarwal
# Processing Record 21 of Set 5 | jiquilisco
# Processing Record 22 of Set 5 | malango
# Processing Record 23 of Set 5 | fale old settlement
# Processing Record 24 of Set 5 | yagry
# City not found. Skipping...
# Processing Record 25 of Set 5 | suhbaatar
# Processing Record 26 of Set 5 | yanbu
# Processing Record 27 of Set 5 | lospalos
# Processing Record 28 of Set 5 | karratha
# Processing Record 29 of Set 5 | rosso
# Processing Record 30 of Set 5 | pangody
# Processing Record 31 of Set 5 | nantucket
# Processing Record 32 of Set 5 | khawr fakkan
# Processing Record 33 of Set 5 | kitimat
# Processing Record 34 of Set 5 | elk city
# Processing Record 35 of Set 5 | prado
# Processing Record 36 of Set 5 | i-n-salah
# Processing Record 37 of Set 5 | la passe
# Processing Record 38 of Set 5 | ulsteinvik
# Processing Record 39 of Set 5 | azul
# Processing Record 40 of Set 5 | portoferraio
# Processing Record 41 of Set 5 | villa canas
# Processing Record 42 of Set 5 | glace bay
# Processing Record 43 of Set 5 | porto novo
# Processing Record 44 of Set 5 | ajaccio
# Processing Record 45 of Set 5 | kodinsk
# Processing Record 46 of Set 5 | lihue
# Processing Record 47 of Set 5 | turpan
# Processing Record 48 of Set 5 | tandil
# Processing Record 49 of Set 5 | piton saint-leu
# Processing Record 0 of Set 6 | port mathurin
# Processing Record 1 of Set 6 | juan griego
# Processing Record 2 of Set 6 | nabire
# Processing Record 3 of Set 6 | tejen
# Processing Record 4 of Set 6 | seogwipo
# City not found. Skipping...
# Processing Record 5 of Set 6 | gandorhun
# Processing Record 6 of Set 6 | shahrud
# Processing Record 7 of Set 6 | le vauclin
# Processing Record 8 of Set 6 | hamilton
# Processing Record 9 of Set 6 | sao miguel dos campos
# Processing Record 10 of Set 6 | colonia
# Processing Record 11 of Set 6 | murghob
# Processing Record 12 of Set 6 | melipilla
# Processing Record 13 of Set 6 | sumbe
# Processing Record 14 of Set 6 | wau
# Processing Record 15 of Set 6 | san patricio
# Processing Record 16 of Set 6 | lazaro cardenas
# Processing Record 17 of Set 6 | kayangel
# Processing Record 18 of Set 6 | cabo san lucas
# Processing Record 19 of Set 6 | toga village
# City not found. Skipping...
# Processing Record 20 of Set 6 | saint-francois
# Processing Record 21 of Set 6 | mashhad
# Processing Record 22 of Set 6 | kerikeri
# Processing Record 23 of Set 6 | frenda
# Processing Record 24 of Set 6 | vorgashor
# Processing Record 25 of Set 6 | luderitz
# Processing Record 26 of Set 6 | annau
# Processing Record 27 of Set 6 | lukolela
# Processing Record 28 of Set 6 | lashio
# Processing Record 29 of Set 6 | puerto san carlos
# City not found. Skipping...
# Processing Record 30 of Set 6 | leh
# Processing Record 31 of Set 6 | tegueste
# Processing Record 32 of Set 6 | argo
# Processing Record 33 of Set 6 | port alfred
# Processing Record 34 of Set 6 | bayan nur
# City not found. Skipping...
# Processing Record 35 of Set 6 | ueno-ebisumachi
# Processing Record 36 of Set 6 | syanno
# Processing Record 37 of Set 6 | bereznehuvate
# Processing Record 38 of Set 6 | novodvinsk
# Processing Record 39 of Set 6 | kapa'a
# Processing Record 40 of Set 6 | khandyga
# Processing Record 41 of Set 6 | sonsorol village
# City not found. Skipping...
# Processing Record 42 of Set 6 | saint-philippe
# Processing Record 43 of Set 6 | crane
# Processing Record 44 of Set 6 | isabela
# Processing Record 45 of Set 6 | tobi village
# City not found. Skipping...
# Processing Record 46 of Set 6 | los alamos
# Processing Record 47 of Set 6 | cockburn town
# Processing Record 48 of Set 6 | azemmour
# Processing Record 49 of Set 6 | qaryat suluq
# Processing Record 0 of Set 7 | brooks
# Processing Record 1 of Set 7 | naze
# Processing Record 2 of Set 7 | suwayr
# Processing Record 3 of Set 7 | morondava
# Processing Record 4 of Set 7 | bojnurd
# Processing Record 5 of Set 7 | keflavik
# Processing Record 6 of Set 7 | mont-dore
# Processing Record 7 of Set 7 | yarmouth
# Processing Record 8 of Set 7 | el haouaria
# Processing Record 9 of Set 7 | revelstoke
# Processing Record 10 of Set 7 | praia da vitoria
# Processing Record 11 of Set 7 | sidney
# Processing Record 12 of Set 7 | atherton
# Processing Record 13 of Set 7 | nuuk
# Processing Record 14 of Set 7 | ringkobing
# Processing Record 15 of Set 7 | tobelo
# Processing Record 16 of Set 7 | krasnoarmeysk
# Processing Record 17 of Set 7 | sao jose da coroa grande
# Processing Record 18 of Set 7 | santa elena de uairen
# Processing Record 19 of Set 7 | richards bay
# Processing Record 20 of Set 7 | kuanda
# Processing Record 21 of Set 7 | vadso
# Processing Record 22 of Set 7 | isetskoye
# Processing Record 23 of Set 7 | howrah
# Processing Record 24 of Set 7 | lufilufi
# Processing Record 25 of Set 7 | tura
# Processing Record 26 of Set 7 | padangsidempuan
# Processing Record 27 of Set 7 | san pedro
# Processing Record 28 of Set 7 | mount pearl
# Processing Record 29 of Set 7 | kununurra
# Processing Record 30 of Set 7 | boende
# Processing Record 31 of Set 7 | sedrata
# Processing Record 32 of Set 7 | palu
# Processing Record 33 of Set 7 | kangding
# Processing Record 34 of Set 7 | nagornyy
# Processing Record 35 of Set 7 | mbanza-ngungu
# Processing Record 36 of Set 7 | balkanabat
# Processing Record 37 of Set 7 | berdigestyakh
# Processing Record 38 of Set 7 | egilsstadir
# Processing Record 39 of Set 7 | alofi
# Processing Record 40 of Set 7 | verkhnevilyuysk
# Processing Record 41 of Set 7 | bovalino
# Processing Record 42 of Set 7 | opuwo
# Processing Record 43 of Set 7 | rajgir
# Processing Record 44 of Set 7 | kolwezi
# Processing Record 45 of Set 7 | ta`u
# Processing Record 46 of Set 7 | nova sintra
# Processing Record 47 of Set 7 | wenchang
# Processing Record 48 of Set 7 | san ignacio de velasco
# Processing Record 49 of Set 7 | twon-brass
# Processing Record 0 of Set 8 | hobyo
# Processing Record 1 of Set 8 | bocaiuva
# Processing Record 2 of Set 8 | zouerate
# Processing Record 3 of Set 8 | ciudad lazaro cardenas
# Processing Record 4 of Set 8 | sarmiento
# Processing Record 5 of Set 8 | port lincoln
# Processing Record 6 of Set 8 | kokopo
# Processing Record 7 of Set 8 | al kharijah
# Processing Record 8 of Set 8 | newman
# Processing Record 9 of Set 8 | kingston
# Processing Record 10 of Set 8 | hayma'
# City not found. Skipping...
# Processing Record 11 of Set 8 | sillamae
# Processing Record 12 of Set 8 | ketchikan
# Processing Record 13 of Set 8 | labrador city
# Processing Record 14 of Set 8 | udachny
# Processing Record 15 of Set 8 | upington
# Processing Record 16 of Set 8 | kapuskasing
# Processing Record 17 of Set 8 | mammoth lakes
# Processing Record 18 of Set 8 | isangel
# Processing Record 19 of Set 8 | port-gentil
# Processing Record 20 of Set 8 | male
# Processing Record 21 of Set 8 | quellon
# Processing Record 22 of Set 8 | marinhas
# Processing Record 23 of Set 8 | ciudad acuna
# Processing Record 24 of Set 8 | alice springs
# Processing Record 25 of Set 8 | bereket
# Processing Record 26 of Set 8 | dragasani
# Processing Record 27 of Set 8 | safaga
# Processing Record 28 of Set 8 | sisimiut
# Processing Record 29 of Set 8 | dalandzadgad
# Processing Record 30 of Set 8 | pisco
# Processing Record 31 of Set 8 | sandnessjoen
# Processing Record 32 of Set 8 | dunedin
# Processing Record 33 of Set 8 | hassi messaoud
# Processing Record 34 of Set 8 | salinopolis
# Processing Record 35 of Set 8 | ancud
# Processing Record 36 of Set 8 | mossel bay
# Processing Record 37 of Set 8 | san rafael
# Processing Record 38 of Set 8 | shantobe
# Processing Record 39 of Set 8 | choibalsan
# Processing Record 40 of Set 8 | westport
# Processing Record 41 of Set 8 | zaragoza
# Processing Record 42 of Set 8 | nuku'alofa
# Processing Record 43 of Set 8 | wenatchee
# Processing Record 44 of Set 8 | waingapu
# Processing Record 45 of Set 8 | creston
# Processing Record 46 of Set 8 | bonthe
# Processing Record 47 of Set 8 | fruita
# Processing Record 48 of Set 8 | pestravka
# Processing Record 49 of Set 8 | okhotsk
# Processing Record 0 of Set 9 | rikaze
# Processing Record 1 of Set 9 | puerto santa
# Processing Record 2 of Set 9 | jiangmen
# Processing Record 3 of Set 9 | montlucon
# Processing Record 4 of Set 9 | freetown
# Processing Record 5 of Set 9 | qamdo
# Processing Record 6 of Set 9 | ventspils
# Processing Record 7 of Set 9 | tokamachi
# City not found. Skipping...
# Processing Record 8 of Set 9 | chaoyang
# Processing Record 9 of Set 9 | conde
# Processing Record 10 of Set 9 | fuvahmulah
# City not found. Skipping...
# Processing Record 11 of Set 9 | san antonio de pale
# Processing Record 12 of Set 9 | jiuquan
# Processing Record 13 of Set 9 | banda aceh
# Processing Record 14 of Set 9 | santyoku
# Processing Record 15 of Set 9 | arraial do cabo
# Processing Record 16 of Set 9 | puerto baquerizo moreno
# Processing Record 17 of Set 9 | svirsk
# Processing Record 18 of Set 9 | mabamba
# Processing Record 19 of Set 9 | yuxia
# Processing Record 20 of Set 9 | howard springs
# Processing Record 21 of Set 9 | al jawf
# Processing Record 22 of Set 9 | nova xavantina
# Processing Record 23 of Set 9 | sucua
# Processing Record 24 of Set 9 | betio village
# Processing Record 25 of Set 9 | paita
# Processing Record 26 of Set 9 | el jadid
# Processing Record 27 of Set 9 | la gi
# Processing Record 28 of Set 9 | minab
# Processing Record 29 of Set 9 | alegrete
# Processing Record 30 of Set 9 | ilha de mocambique
# Processing Record 31 of Set 9 | urangan
# Processing Record 32 of Set 9 | aasiaat
# Processing Record 33 of Set 9 | miramichi
# Processing Record 34 of Set 9 | lethem
# Processing Record 35 of Set 9 | kismayo
# Processing Record 36 of Set 9 | osakarovka
# Processing Record 37 of Set 9 | poronaysk
# Processing Record 38 of Set 9 | bom jesus
# Processing Record 39 of Set 9 | mandaguari
# Processing Record 40 of Set 9 | rawai
# Processing Record 41 of Set 9 | lensk
# Processing Record 42 of Set 9 | petrovka
# Processing Record 43 of Set 9 | varena
# Processing Record 44 of Set 9 | chhindwara
# Processing Record 45 of Set 9 | east london
# Processing Record 46 of Set 9 | ust'-ilimsk
# Processing Record 47 of Set 9 | longjing
# Processing Record 48 of Set 9 | viqueque
# Processing Record 49 of Set 9 | taroudant
# Processing Record 0 of Set 10 | abadeh
# Processing Record 1 of Set 10 | tralee
# Processing Record 2 of Set 10 | northam
# Processing Record 3 of Set 10 | port hedland
# Processing Record 4 of Set 10 | rongelap
# Processing Record 5 of Set 10 | taltal
# Processing Record 6 of Set 10 | jiangyou
# Processing Record 7 of Set 10 | mollendo
# Processing Record 8 of Set 10 | inirida
# Processing Record 9 of Set 10 | raja sansi
# Processing Record 10 of Set 10 | douglas
# Processing Record 11 of Set 10 | sand springs
# Processing Record 12 of Set 10 | preobrazheniye
# Processing Record 13 of Set 10 | inhambane
# Processing Record 14 of Set 10 | carmelo
# Processing Record 15 of Set 10 | peterborough
# Processing Record 16 of Set 10 | statesboro
# Processing Record 17 of Set 10 | mana
# Processing Record 18 of Set 10 | tawau
# Processing Record 19 of Set 10 | port macquarie
# Processing Record 20 of Set 10 | san pascual
# Processing Record 21 of Set 10 | susuman
# Processing Record 22 of Set 10 | caleta de carquin
# Processing Record 23 of Set 10 | tapes
# Processing Record 24 of Set 10 | lhokseumawe
# Processing Record 25 of Set 10 | holualoa
# Processing Record 26 of Set 10 | beyla
# Processing Record 27 of Set 10 | chegdomyn
# Processing Record 28 of Set 10 | morristown
# Processing Record 29 of Set 10 | pitimbu
# Processing Record 30 of Set 10 | sittwe
# Processing Record 31 of Set 10 | gisborne
# Processing Record 32 of Set 10 | kearney
# Processing Record 33 of Set 10 | fort abbas
# Processing Record 34 of Set 10 | urumqi
# Processing Record 35 of Set 10 | severo-yeniseyskiy
# Processing Record 36 of Set 10 | puyang chengguanzhen
# Processing Record 37 of Set 10 | hammerfest
# Processing Record 38 of Set 10 | beruniy
# Processing Record 39 of Set 10 | hadibu
# Processing Record 40 of Set 10 | bethanie
# Processing Record 41 of Set 10 | belem de sao francisco
# Processing Record 42 of Set 10 | tofol
# Processing Record 43 of Set 10 | sergeyevka
# Processing Record 44 of Set 10 | minas de marcona
# Processing Record 45 of Set 10 | santa cruz del norte
# Processing Record 46 of Set 10 | luanda
# Processing Record 47 of Set 10 | akcaabat
# Processing Record 48 of Set 10 | port sudan
# Processing Record 49 of Set 10 | buulobarde
# Processing Record 0 of Set 11 | cabedelo
# Processing Record 1 of Set 11 | catriel
# Processing Record 2 of Set 11 | zhangjiakou shi xuanhua qu
# Processing Record 3 of Set 11 | lokhvytsya
# Processing Record 4 of Set 11 | wesley chapel
# Processing Record 5 of Set 11 | solnechnyy
# Processing Record 6 of Set 11 | bandon
# Processing Record 7 of Set 11 | celestun
# Processing Record 8 of Set 11 | cill airne
# Processing Record 9 of Set 11 | angel r. cabada
# Processing Record 10 of Set 11 | new plymouth
# Processing Record 11 of Set 11 | hasaki
# Processing Record 12 of Set 11 | tarhuna
# Processing Record 13 of Set 11 | ghat
# Processing Record 14 of Set 11 | dambatta
# Processing Record 15 of Set 11 | milton-freewater
# Processing Record 16 of Set 11 | haiku-pauwela
# Processing Record 17 of Set 11 | bafoulabe
# Processing Record 18 of Set 11 | shahpura
# Processing Record 19 of Set 11 | pedernales
# Processing Record 20 of Set 11 | kpandu
# Processing Record 21 of Set 11 | gamba
# Processing Record 22 of Set 11 | addiet canna
# Processing Record 23 of Set 11 | demyansk
# Processing Record 24 of Set 11 | aioun
# Processing Record 25 of Set 11 | maxixe
# Processing Record 26 of Set 11 | aktau
# Processing Record 27 of Set 11 | ambovombe
# Processing Record 28 of Set 11 | fort st. john
# Processing Record 29 of Set 11 | usogorsk
# Processing Record 30 of Set 11 | meads
# Processing Record 31 of Set 11 | nova venecia
# Processing Record 32 of Set 11 | east haddam
# Processing Record 33 of Set 11 | lodwar
# Processing Record 34 of Set 11 | lepsy
# Processing Record 35 of Set 11 | saint cloud
# Processing Record 36 of Set 11 | vingt cinq
# City not found. Skipping...
# Processing Record 37 of Set 11 | batamshinskiy
# Processing Record 38 of Set 11 | san luis potosi
# Processing Record 39 of Set 11 | gweru
# Processing Record 40 of Set 11 | melendugno
# Processing Record 41 of Set 11 | al-`ula
# City not found. Skipping...
# Processing Record 42 of Set 11 | lijiang
# Processing Record 43 of Set 11 | we
# City not found. Skipping...
# Processing Record 44 of Set 11 | galliano
# Processing Record 45 of Set 11 | punta del este
# Processing Record 46 of Set 11 | an nuhud
# Processing Record 47 of Set 11 | darende
# Processing Record 48 of Set 11 | darwin
# Processing Record 49 of Set 11 | miles city
# Processing Record 0 of Set 12 | rondonopolis
# Processing Record 1 of Set 12 | yuzhno-kurilsk
# Processing Record 2 of Set 12 | kuloy
# Processing Record 3 of Set 12 | touros
# Processing Record 4 of Set 12 | campo maior
# Processing Record 5 of Set 12 | tevragh zeina
# City not found. Skipping...
# Processing Record 6 of Set 12 | tocopilla
# Processing Record 7 of Set 12 | shakawe
# Processing Record 8 of Set 12 | thames
# Processing Record 9 of Set 12 | ugoofaaru
# Processing Record 10 of Set 12 | sao joao da barra
# Processing Record 11 of Set 12 | lamar
# Processing Record 12 of Set 12 | benghazi
# Processing Record 13 of Set 12 | alaghsas
# Processing Record 14 of Set 12 | am djarass
# City not found. Skipping...
# Processing Record 15 of Set 12 | nili
# Processing Record 16 of Set 12 | goure
# Processing Record 17 of Set 12 | kunyang
# Processing Record 18 of Set 12 | mahdia
# Processing Record 19 of Set 12 | pasuquin
# Processing Record 20 of Set 12 | ploneour-lanvern
# Processing Record 21 of Set 12 | namsos
# Processing Record 22 of Set 12 | mafinga
# Processing Record 23 of Set 12 | cartersville
# Processing Record 24 of Set 12 | awjilah
# Processing Record 25 of Set 12 | belle fourche
# Processing Record 26 of Set 12 | ararangua
# Processing Record 27 of Set 12 | mburucuya
# Processing Record 28 of Set 12 | selfoss
# Processing Record 29 of Set 12 | bomdila
# Processing Record 30 of Set 12 | villamontes
# Processing Record 31 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 32 of Set 12 | harper
# Processing Record 33 of Set 12 | ar rutbah
# Processing Record 34 of Set 12 | neiafu
# Processing Record 35 of Set 12 | yemetsk
# Processing Record 36 of Set 12 | kainantu
# Processing Record 37 of Set 12 | dickinson
# Processing Record 38 of Set 12 | magway
# Processing Record 39 of Set 12 | dossor
# Processing Record 40 of Set 12 | tabalah
# Processing Record 41 of Set 12 | manaure
# Processing Record 42 of Set 12 | nizhnyaya salda
# Processing Record 43 of Set 12 | iwaki
# Processing Record 44 of Set 12 | sao gabriel da cachoeira
# Processing Record 45 of Set 12 | kurumul
# City not found. Skipping...
# Processing Record 46 of Set 12 | kannad
# Processing Record 47 of Set 12 | nechi
# Processing Record 48 of Set 12 | pathein
# Processing Record 49 of Set 12 | papao
# Processing Record 0 of Set 13 | oamaru
# Processing Record 1 of Set 13 | barcelos
# Processing Record 2 of Set 13 | strugi-krasnyye
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          575
# Lat           575
# Lng           575
# Max Temp      575
# Humidity      575
# Cloudiness    575
# Wind Speed    575
# Country       575
# Date          575
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0           qaqortoq  60.7167 -46.0333    -21.54        66           4
# 1            pokhara  28.2333  83.9833      8.34        47          26
# 2  port-aux-francais -49.3500  70.2167      5.09        68          98
# 3            ushuaia -54.8000 -68.3000     16.81        42           0
# 4          vredefort -27.0081  27.3646     22.69        36         100
#
#    Wind Speed Country        Date
# 0        3.17      GL  1706221386
# 1        2.39      NP  1706221511
# 2       12.56      TF  1706221512
# 3        7.72      AR  1706221513
# 4        1.04      ZA  1706221513

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 qaqortoq  60.7167 -46.0333    -21.54        66           4
# 1                  pokhara  28.2333  83.9833      8.34        47          26
# 2        port-aux-francais -49.3500  70.2167      5.09        68          98
# 3                  ushuaia -54.8000 -68.3000     16.81        42           0
# 4                vredefort -27.0081  27.3646     22.69        36         100
#
#          Wind Speed Country        Date
# City_ID
# 0              3.17      GL  1706221386
# 1              2.39      NP  1706221511
# 2             12.56      TF  1706221512
# 3              7.72      AR  1706221513
# 4              1.04      ZA  1706221513

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Below information pulled from https://stackoverflow.com/questions/3682748/converting-unix-timestamp-string-to-readable-date
# Convert Date from Unix to UTC
from datetime import datetime
unix_timestamp = city_date
utc_time = datetime.utcfromtimestamp(unix_timestamp)
utc_date = utc_time.strftime("%Y-%m-%d (UTC)")
utc_date
# Out:
# '2024-01-25 (UTC)'

# %%
# Build scatter plot for latitude vs. temperature
lat_x = city_data_df["Lat"]
temp_y = city_data_df["Max Temp"]
plt.scatter(lat_x, temp_y, edgecolors = "black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title(f"City Latitude vs Max Temperature ({utc_date})")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
humidity_y = city_data_df["Humidity"]
plt.scatter(lat_x, humidity_y, edgecolors = "black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs Humidity ({utc_date})")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
cloud_y = city_data_df["Cloudiness"]
plt.scatter(lat_x, cloud_y, edgecolors = "black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs Cloudiness ({utc_date})")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
wind_y = city_data_df["Wind Speed"]
plt.scatter(lat_x, wind_y, edgecolors = "black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title(f"City Latitude vs Wind Speed ({utc_date})")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def reg_line(x_axis, y_axis):
    plt.scatter(x_axis, y_axis, edgecolors = "black")
    plt.xlabel("Latitude")
    plt.grid()
    res = linregress(x_axis, y_axis)  
    linreg = res.slope*x_axis+res.intercept
    plt.plot(x_axis, linreg, "r")
    show_eq = "y =" + str(round(res.slope, 2)) + "x +" + str(round(res.intercept,2))
    plt.annotate(show_eq, (x_axis.min()+20,y_axis.min()+5), color = "red", fontsize = 15)
    print(f"The r-value is: {res.rvalue}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"]>=0), :]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          qaqortoq  60.7167 -46.0333    -21.54        66           4
# 1           pokhara  28.2333  83.9833      8.34        47          26
# 5            bethel  41.3712 -73.4140     11.93        82          75
# 6        kincardine  56.0667  -3.7167     12.15        88          97
# 8            albany  42.6001 -73.9662      5.23        77         100
#
#          Wind Speed Country        Date
# City_ID
# 0              3.17      GL  1706221386
# 1              2.39      NP  1706221511
# 5              0.00      US  1706221514
# 6              8.35      GB  1706221249
# 8              0.45      US  1706221515

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"]<0), :]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2        port-aux-francais -49.3500  70.2167      5.09        68          98
# 3                  ushuaia -54.8000 -68.3000     16.81        42           0
# 4                vredefort -27.0081  27.3646     22.69        36         100
# 7           puerto natales -51.7236 -72.4875     12.81        68         100
# 10                  ndjole  -0.1783  10.7649     25.53        90          24
#
#          Wind Speed Country        Date
# City_ID
# 2             12.56      TF  1706221512
# 3              7.72      AR  1706221513
# 4              1.04      ZA  1706221513
# 7              1.96      CL  1706221515
# 10             1.46      GA  1706221516

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
northlat = northern_hemi_df["Lat"]
northtemp = northern_hemi_df["Max Temp"]
reg_line(northlat, northtemp)
plt.ylabel("Max Temperature (C)")
plt.title(f"Northern Hemisphere City Latitude vs Max Temperature ({utc_date})")
plt.show()
# Out:
# The r-value is: -0.8070744972538115

# %%
# Linear regression on Southern Hemisphere
x_axis = southern_hemi_df["Lat"]
y_axis = southern_hemi_df["Max Temp"]
reg_line(x_axis, y_axis)
plt.ylabel("Max Temperature (C)")
plt.title(f"Southern Hemisphere City Latitude vs Max Temperature ({utc_date})")
plt.show()
# Out:
# The r-value is: 0.3824016770214474

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_axis = northern_hemi_df["Lat"]
y_axis = northern_hemi_df["Humidity"]
reg_line(x_axis, y_axis)
plt.ylabel("Humidity (%)")
plt.title(f"Northern Hemisphere City Latitude vs Humidity ({utc_date})")
plt.show()
# Out:
# The r-value is: 0.4548983141923842

# %%
# Southern Hemisphere
x_axis = southern_hemi_df["Lat"]
y_axis = southern_hemi_df["Humidity"]
reg_line(x_axis, y_axis)
plt.ylabel("Humidity (%)")
plt.title(f"Southern Hemisphere City Latitude vs Humidity ({utc_date})")
plt.show()
# Out:
# The r-value is: 0.4879268712951326

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
